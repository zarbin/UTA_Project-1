# %% [markdown]
# ########################################################################################################################
# #File: DataPull_Redfine_county.ipynb
# #Source: https://redfin-public-data.s3.us-west-2.amazonaws.com/redfin_market_tracker/
# #Status: Active - Main real estate data pull
# #Notes: Pull county level data from Redfine
# #Last updated = 11/20/2022
# ########################################################################################################################

# %%
import requests
import json
from datetime import datetime
import pandas as pd
import warnings
import os

warnings.filterwarnings('ignore')

# %%
#url link from - https://www.redfin.com/news/data-center/
#reads in national county level real estate market data
#Duration period: 30

url = 'https://redfin-public-data.s3.us-west-2.amazonaws.com/redfin_market_tracker/county_market_tracker.tsv000.gz'


#assign to dataframe
df = pd.read_csv(url, compression='gzip', sep='\t', on_bad_lines='skip')

print('Num of rows:', len(df))
print('Num of cols:', len(df.columns)) 

#preview data
df.head()
# Out:
# Num of rows: 784430
# Num of cols: 58
#   period_begin  period_end  period_duration region_type  region_type_id  \
# 0   2014-12-01  2014-12-31               30      county               5
# 1   2013-04-01  2013-04-30               30      county               5
# 2   2020-03-01  2020-03-31               30      county               5
# 3   2017-05-01  2017-05-31               30      county               5
# 4   2016-05-01  2016-05-31               30      county               5
#
#    table_id is_seasonally_adjusted                 region  city         state  \
# 0      2243                      f  Washington County, OH   NaN          Ohio
# 1      3085                      f      Island County, WA   NaN    Washington
# 2       730                      f      DeKalb County, IL   NaN      Illinois
# 3      2382                      f     Dauphin County, PA   NaN  Pennsylvania
# 4       996                      f      Warren County, IA   NaN          Iowa
#
#    ... sold_above_list_yoy price_drops  price_drops_mom  price_drops_yoy  \
# 0  ...           -0.021552         NaN              NaN              NaN
# 1  ...            0.035940    0.177496         0.001771        -0.056232
# 2  ...            0.045822    0.200730         0.006931        -0.056696
# 3  ...            0.000000         NaN              NaN              NaN
# 4  ...            0.128527         NaN              NaN              NaN
#
#    off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# 0                 0.000000                    -0.055556
# 1                 0.447059                     0.027704
# 2                 0.604167                     0.044845
# 3                      NaN                          NaN
# 4                 0.081081                    -0.108108
#
#    off_market_in_two_weeks_yoy  parent_metro_region  \
# 0                     0.000000         Marietta, OH
# 1                     0.172549       Oak Harbor, WA
# 2                     0.066352            Elgin, IL
# 3                          NaN       Harrisburg, PA
# 4                     0.081081       Des Moines, IA
#
#    parent_metro_region_metro_code         last_updated
# 0                         31930.0  2022-11-20 14:36:43
# 1                         36020.0  2022-11-20 14:36:43
# 2                         20994.0  2022-11-20 14:36:43
# 3                         25420.0  2022-11-20 14:36:43
# 4                         19780.0  2022-11-20 14:36:43
#
# [5 rows x 58 columns]

# %%
#Filter data and clean-up

#filter real estate dataset on Texas
texas_df = df.loc[df['state'] == 'Texas']

#drop columns we don't need
texas_df.drop(texas_df.columns[[2, 3, 4, 5, 6, 8]], axis=1, inplace=True)

#region column isolate zipcode into new column 'zipcode'
texas_df['county'] = texas_df.apply(lambda x: x['region'].split(',')[0].strip(), axis=1)


#list if counties to focus on
counties_list = ['Williamson County', 'Travis County', 'Hays County', 'Bastrop County', 'Caldwell County']

#filter texas dataset to counties we are interested in
texas_counties_df = texas_df.loc[texas_df['county'].isin(counties_list)]


texas_counties_df.head()

#csv export
#texas_counties_df.to_csv('redfin_texas_counties.csv')
# Out:
#      period_begin  period_end                 region  state state_code  \
# 139    2012-01-01  2012-01-31  Williamson County, TX  Texas         TX
# 299    2019-05-01  2019-05-31  Williamson County, TX  Texas         TX
# 474    2019-06-01  2019-06-30  Williamson County, TX  Texas         TX
# 505    2012-04-01  2012-04-30  Williamson County, TX  Texas         TX
# 1400   2015-08-01  2015-08-31  Williamson County, TX  Texas         TX
#
#                   property_type  property_type_id  median_sale_price  \
# 139     Multi-Family (2-4 Unit)                 4           152500.0
# 299                 Condo/Co-op                 3           237000.0
# 474   Single Family Residential                 6           291000.0
# 505     Multi-Family (2-4 Unit)                 4           154950.0
# 1400    Multi-Family (2-4 Unit)                 4           219000.0
#
#       median_sale_price_mom  median_sale_price_yoy  ...  price_drops  \
# 139                0.155303               0.270833  ...     0.043478
# 299                0.013904               0.068771  ...     0.212766
# 474               -0.029863              -0.017722  ...     0.336561
# 505                0.029568              -0.123090  ...     0.113636
# 1400               0.120205               0.084158  ...          NaN
#
#       price_drops_mom  price_drops_yoy  off_market_in_two_weeks  \
# 139         -0.164855        -0.096307                 0.400000
# 299         -0.187234        -0.103024                 0.571429
# 474          0.040325        -0.032895                 0.505759
# 505         -0.021499        -0.069462                 0.571429
# 1400              NaN              NaN                 0.777778
#
#       off_market_in_two_weeks_mom  off_market_in_two_weeks_yoy  \
# 139                     -0.400000                     0.066667
# 299                     -0.211180                     0.071429
# 474                     -0.006931                     0.056208
# 505                      0.171429                     0.428571
# 1400                     0.215278                     0.777778
#
#       parent_metro_region  parent_metro_region_metro_code  \
# 139            Austin, TX                         12420.0
# 299            Austin, TX                         12420.0
# 474            Austin, TX                         12420.0
# 505            Austin, TX                         12420.0
# 1400           Austin, TX                         12420.0
#
#              last_updated             county
# 139   2022-11-20 14:36:43  Williamson County
# 299   2022-11-20 14:36:43  Williamson County
# 474   2022-11-20 14:36:43  Williamson County
# 505   2022-11-20 14:36:43  Williamson County
# 1400  2022-11-20 14:36:43  Williamson County
#
# [5 rows x 53 columns]

# %%
#preview
print('Num of rows:', len(texas_counties_df))
texas_counties_df.head()
# Out:
# Num of rows: 2573
#      period_begin  period_end                 region  state state_code  \
# 139    2012-01-01  2012-01-31  Williamson County, TX  Texas         TX
# 299    2019-05-01  2019-05-31  Williamson County, TX  Texas         TX
# 474    2019-06-01  2019-06-30  Williamson County, TX  Texas         TX
# 505    2012-04-01  2012-04-30  Williamson County, TX  Texas         TX
# 1400   2015-08-01  2015-08-31  Williamson County, TX  Texas         TX
#
#                   property_type  property_type_id  median_sale_price  \
# 139     Multi-Family (2-4 Unit)                 4           152500.0
# 299                 Condo/Co-op                 3           237000.0
# 474   Single Family Residential                 6           291000.0
# 505     Multi-Family (2-4 Unit)                 4           154950.0
# 1400    Multi-Family (2-4 Unit)                 4           219000.0
#
#       median_sale_price_mom  median_sale_price_yoy  ...  price_drops  \
# 139                0.155303               0.270833  ...     0.043478
# 299                0.013904               0.068771  ...     0.212766
# 474               -0.029863              -0.017722  ...     0.336561
# 505                0.029568              -0.123090  ...     0.113636
# 1400               0.120205               0.084158  ...          NaN
#
#       price_drops_mom  price_drops_yoy  off_market_in_two_weeks  \
# 139         -0.164855        -0.096307                 0.400000
# 299         -0.187234        -0.103024                 0.571429
# 474          0.040325        -0.032895                 0.505759
# 505         -0.021499        -0.069462                 0.571429
# 1400              NaN              NaN                 0.777778
#
#       off_market_in_two_weeks_mom  off_market_in_two_weeks_yoy  \
# 139                     -0.400000                     0.066667
# 299                     -0.211180                     0.071429
# 474                     -0.006931                     0.056208
# 505                      0.171429                     0.428571
# 1400                     0.215278                     0.777778
#
#       parent_metro_region  parent_metro_region_metro_code  \
# 139            Austin, TX                         12420.0
# 299            Austin, TX                         12420.0
# 474            Austin, TX                         12420.0
# 505            Austin, TX                         12420.0
# 1400           Austin, TX                         12420.0
#
#              last_updated             county
# 139   2022-11-20 14:36:43  Williamson County
# 299   2022-11-20 14:36:43  Williamson County
# 474   2022-11-20 14:36:43  Williamson County
# 505   2022-11-20 14:36:43  Williamson County
# 1400  2022-11-20 14:36:43  Williamson County
#
# [5 rows x 53 columns]

# %%
texas_counties_df.info()
texas_counties_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36694 entries, 3883 to 352612
# Data columns (total 52 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   period_begin                    36694 non-null  object
#  1   period_end                      36694 non-null  object
#  2   region                          36694 non-null  object
#  3   state                           36694 non-null  object
#  4   state_code                      36694 non-null  object
#  5   property_type                   36694 non-null  object
#  6   property_type_id                36694 non-null  int64
#  7   median_sale_price               36694 non-null  float64
#  8   median_sale_price_mom           35328 non-null  float64
#  9   median_sale_price_yoy           33193 non-null  float64
#  10  median_list_price               34670 non-null  float64
#  11  median_list_price_mom           33219 non-null  float64
#  12  median_list_price_yoy           31536 non-null  float64
#  13  median_ppsf                     36690 non-null  float64
#  14  median_ppsf_mom                 35324 non-null  float64
#  15  median_ppsf_yoy                 33188 non-null  float64
#  16  median_list_ppsf                34670 non-null  float64
#  17  median_list_ppsf_mom            33219 non-null  float64
#  18  median_list_ppsf_yoy            31536 non-null  float64
#  19  homes_sold                      36694 non-null  int64
#  20  homes_sold_mom                  35328 non-null  float64
#  21  homes_sold_yoy                  33193 non-null  float64
#  22  pending_sales                   29533 non-null  float64
#  23  pending_sales_mom               26598 non-null  float64
#  24  pending_sales_yoy               26081 non-null  float64
#  25  new_listings                    34672 non-null  float64
#  26  new_listings_mom                33220 non-null  float64
#  27  new_listings_yoy                31540 non-null  float64
#  28  inventory                       32563 non-null  float64
#  29  inventory_mom                   31061 non-null  float64
#  30  inventory_yoy                   29689 non-null  float64
#  31  median_dom                      36570 non-null  float64
#  32  median_dom_mom                  35206 non-null  float64
#  33  median_dom_yoy                  33075 non-null  float64
#  34  avg_sale_to_list                36691 non-null  float64
#  35  avg_sale_to_list_mom            35325 non-null  float64
#  36  avg_sale_to_list_yoy            33189 non-null  float64
#  37  sold_above_list                 36694 non-null  float64
#  38  sold_above_list_mom             35328 non-null  float64
#  39  sold_above_list_yoy             33193 non-null  float64
#  40  price_drops                     25827 non-null  float64
#  41  price_drops_mom                 23249 non-null  float64
#  42  price_drops_yoy                 21598 non-null  float64
#  43  off_market_in_two_weeks         29533 non-null  float64
#  44  off_market_in_two_weeks_mom     26598 non-null  float64
#  45  off_market_in_two_weeks_yoy     26081 non-null  float64
#  46  parent_metro_region             36694 non-null  object
#  47  parent_metro_region_metro_code  36694 non-null  int64
#  48  last_updated                    36694 non-null  object
#  49  zipcode                         36694 non-null  int32
#  50  city                            36694 non-null  object
#  51  county                          36694 non-null  object
# dtypes: float64(38), int32(1), int64(3), object(10)
# memory usage: 14.7+ MB
#        property_type_id  median_sale_price  median_sale_price_mom  \
# count      36694.000000       3.669400e+04           35328.000000
# mean           3.789148       3.499373e+05               0.018734
# std            4.091990       2.209501e+05               0.177104
# min           -1.000000       2.750000e+03              -0.996642
# 25%           -1.000000       2.070000e+05              -0.017335
# 50%            4.000000       2.950000e+05               0.000000
# 75%            6.000000       4.320000e+05               0.034556
# max           13.000000       3.875000e+06               5.235731
#
#        median_sale_price_yoy  median_list_price  median_list_price_mom  \
# count           33193.000000       3.467000e+04           33219.000000
# mean                0.155398       3.701842e+05               0.041076
# std                 0.400311       2.453578e+05               2.724775
# min                -0.996382       1.300000e+03              -0.997840
# 25%                 0.017647       2.199000e+05              -0.019737
# 50%                 0.097143       3.100000e+05               0.000000
# 75%                 0.219958       4.500000e+05               0.036628
# max                14.825243       8.000000e+06             454.555556
#
#        median_list_price_yoy   median_ppsf  median_ppsf_mom  median_ppsf_yoy  \
# count           31536.000000  36690.000000     35324.000000     33188.000000
# mean                0.168039    193.231848         0.014200         0.140672
# std                 2.673111    122.643604         0.138051         0.557558
# min                -0.998071      1.286249        -0.993643        -0.993149
# 25%                 0.014146    122.561359        -0.009943         0.028887
# 50%                 0.089285    161.959221         0.000957         0.089781
# 75%                 0.202802    237.448547         0.026829         0.188508
# max               257.322692   8021.944405         5.630782        58.622673
#
#        ...  sold_above_list_mom  sold_above_list_yoy   price_drops  \
# count  ...         35328.000000         33193.000000  25827.000000
# mean   ...             0.000372             0.033266      0.586626
# std    ...             0.137281             0.266363      0.236425
# min    ...            -1.000000            -1.000000      0.020000
# 25%    ...            -0.027778            -0.048469      0.417910
# 50%    ...             0.000000             0.002994      0.578947
# 75%    ...             0.029412             0.113321      0.750000
# max    ...             1.000000             1.000000      1.000000
#
#        price_drops_mom  price_drops_yoy  off_market_in_two_weeks  \
# count     23249.000000     21598.000000             29533.000000
# mean          0.008908        -0.001757                 0.433720
# std           0.185772         0.246642                 0.284525
# min          -0.875000        -0.952381                 0.000000
# 25%          -0.079406        -0.136657                 0.250000
# 50%           0.006352         0.000000                 0.435714
# 75%           0.100733         0.133887                 0.600000
# max           0.875000         0.947368                 1.000000
#
#        off_market_in_two_weeks_mom  off_market_in_two_weeks_yoy  \
# count                 26598.000000                 26081.000000
# mean                     -0.002602                    -0.001654
# std                       0.304983                     0.313095
# min                      -1.000000                    -1.000000
# 25%                      -0.129533                    -0.141324
# 50%                       0.000000                     0.000000
# 75%                       0.120728                     0.141700
# max                       1.000000                     1.000000
#
#        parent_metro_region_metro_code       zipcode
# count                    36694.000000  36694.000000
# mean                     12634.648716  78615.785524
# std                       2497.801108    430.555690
# min                      12420.000000  76527.000000
# 25%                      12420.000000  78648.000000
# 50%                      12420.000000  78720.000000
# 75%                      12420.000000  78744.000000
# max                      41700.000000  78957.000000
#
# [8 rows x 42 columns]
