# %%
import requests
import json
from datetime import datetime
import pandas as pd
import warnings
import os

warnings.filterwarnings('ignore')

# %%
#url link from - https://www.redfin.com/news/data-center/
#reads in national zip code level real estate market data
#Duration period: 90

url = 'https://redfin-public-data.s3.us-west-2.amazonaws.com/redfin_market_tracker/zip_code_market_tracker.tsv000.gz'


#assign to dataframe
df = pd.read_csv(url, compression='gzip', sep='\t', on_bad_lines='skip')

print('Num of rows:', len(df))
print('Num of cols:', len(df.columns)) 

#preview data
df.head()
# Out:
# Num of rows: 6680997
# Num of cols: 58
#   period_begin  period_end  period_duration region_type  region_type_id  \
# 0   2018-11-01  2019-01-31               90    zip code               2
# 1   2020-12-01  2021-02-28               90    zip code               2
# 2   2015-07-01  2015-09-30               90    zip code               2
# 3   2017-03-01  2017-05-31               90    zip code               2
# 4   2013-03-01  2013-05-31               90    zip code               2
#
#    table_id is_seasonally_adjusted           region  city        state  ...  \
# 0     18999                      f  Zip Code: 45226   NaN         Ohio  ...
# 1      3606                      f  Zip Code: 11003   NaN     New York  ...
# 2      2151                      f  Zip Code: 06107   NaN  Connecticut  ...
# 3     38575                      f  Zip Code: 93063   NaN   California  ...
# 4     39921                      f  Zip Code: 95938   NaN   California  ...
#
#   sold_above_list_yoy price_drops  price_drops_mom  price_drops_yoy  \
# 0            0.000000    0.500000         0.071429         0.166667
# 1            0.183093    0.339286         0.028941        -0.026099
# 2            0.107143         NaN              NaN              NaN
# 3           -0.008333    0.529412         0.029412         0.003096
# 4           -0.282828         NaN              NaN              NaN
#
#    off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# 0                 0.000000                     0.000000
# 1                 0.428571                     0.193277
# 2                 0.500000                          NaN
# 3                 0.444444                     0.019444
# 4                 0.250000                    -0.083333
#
#    off_market_in_two_weeks_yoy  parent_metro_region  \
# 0                     0.000000       Cincinnati, OH
# 1                     0.345238    Nassau County, NY
# 2                     0.500000         Hartford, CT
# 3                    -0.007937           Oxnard, CA
# 4                     0.250000            Chico, CA
#
#    parent_metro_region_metro_code         last_updated
# 0                           17140  2022-11-20 14:36:43
# 1                           35004  2022-11-20 14:36:43
# 2                           25540  2022-11-20 14:36:43
# 3                           37100  2022-11-20 14:36:43
# 4                           17020  2022-11-20 14:36:43
#
# [5 rows x 58 columns]

# %%
# read US zip code data file
# source: https://github.com/zauberware/postal-codes-json-xml-csv/tree/master/data
# Updated 10 months ago

zip_df = pd.read_csv('data\zipcodes.csv')
texas_zip = zip_df.loc[zip_df['state'] == 'Texas']
print('Num of rows: ', len(texas_zip))
print('Num of columns: ', len(texas_zip.columns))

texas_zip.head()
# Out:
# Num of rows:  2600
# Num of columns:  11
#       country_code  zipcode      place  state state_code  province  \
# 33846           US    75763  Frankston  Texas         TX  Anderson
# 33847           US    75779     Neches  Texas         TX  Anderson
# 33848           US    75801  Palestine  Texas         TX  Anderson
# 33849           US    75802  Palestine  Texas         TX  Anderson
# 33850           US    75803  Palestine  Texas         TX  Anderson
#
#        province_code community  community_code  latitude  longitude
# 33846            1.0       NaN             NaN   32.0535   -95.5163
# 33847            1.0       NaN             NaN   31.8668   -95.4958
# 33848            1.0       NaN             NaN   31.7588   -95.6342
# 33849            1.0       NaN             NaN   31.7621   -95.6308
# 33850            1.0       NaN             NaN   31.7571   -95.6545

# %%
#Filter data and clean-up

#filter real estate dataset on Texas
texas_df = df.loc[df['state'] == 'Texas']

#drop columns we don't need
texas_df.drop(texas_df.columns[[2, 3, 4, 5, 6, 8, 37, 38, 39]], axis=1, inplace=True)

#region column isolate zipcode into new column 'zipcode'
texas_df['zipcode'] = texas_df.apply(lambda x: x['region'].split(':')[1].strip(), axis=1)
texas_df['zipcode'] = texas_df['zipcode'].astype(int)

#should check that zip codes are valid and that when we merge/join we aren't losing any data
#looks like around 1000 rows are dropped after the merge

#merge zip code data to add zipcode, city, county fields to original Redfin Real estate data. 
texas_merge_df = pd.merge(
    texas_df,
    texas_zip[['zipcode','place','province']],
    how='inner',
    on=['zipcode']
)

#rename columns
rename_cols = {'place': 'city',
        'province': 'county'}

texas_merge_df.rename(columns=rename_cols,
          inplace=True)

#preview
print('Num of rows:', len(texas_merge_df))
texas_merge_df.head()

#csv export
#texas_merge_df.to_csv('redfin_texas_export_new.csv')
# Out:
# Num of rows: 354096
#   period_begin  period_end           region  state state_code  \
# 0   2016-08-01  2016-10-31  Zip Code: 77067  Texas         TX
# 1   2015-09-01  2015-11-30  Zip Code: 77067  Texas         TX
# 2   2012-04-01  2012-06-30  Zip Code: 77067  Texas         TX
# 3   2018-12-01  2019-02-28  Zip Code: 77067  Texas         TX
# 4   2015-11-01  2016-01-31  Zip Code: 77067  Texas         TX
#
#      property_type  property_type_id  median_sale_price  \
# 0  All Residential                -1           130000.0
# 1  All Residential                -1           118000.0
# 2  All Residential                -1            61375.0
# 3  All Residential                -1           145950.0
# 4  All Residential                -1           125000.0
#
#    median_sale_price_mom  median_sale_price_yoy  ...  price_drops_yoy  \
# 0               0.027668               0.141352  ...        -0.435606
# 1               0.035996               0.092593  ...        -0.019608
# 2               0.006148               0.062311  ...              NaN
# 3              -0.006467              -0.026351  ...              NaN
# 4              -0.003984               0.210654  ...         0.127155
#
#    off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# 0                 0.833333                     0.033333
# 1                 0.500000                     0.000000
# 2                 0.437500                     0.346591
# 3                 0.375000                    -0.125000
# 4                 0.375000                     0.193182
#
#    off_market_in_two_weeks_yoy  parent_metro_region  \
# 0                     0.333333          Houston, TX
# 1                    -0.045455          Houston, TX
# 2                     0.037500          Houston, TX
# 3                     0.175000          Houston, TX
# 4                     0.208333          Houston, TX
#
#    parent_metro_region_metro_code         last_updated  zipcode     city  \
# 0                           26420  2022-11-20 14:36:43    77067  Houston
# 1                           26420  2022-11-20 14:36:43    77067  Houston
# 2                           26420  2022-11-20 14:36:43    77067  Houston
# 3                           26420  2022-11-20 14:36:43    77067  Houston
# 4                           26420  2022-11-20 14:36:43    77067  Houston
#
#    county
# 0  Harris
# 1  Harris
# 2  Harris
# 3  Harris
# 4  Harris
#
# [5 rows x 52 columns]

# %%
texas_merge_df.info()
texas_merge_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 355634 entries, 72 to 6680992
# Data columns (total 50 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   period_begin                    355634 non-null  object
#  1   period_end                      355634 non-null  object
#  2   region                          355634 non-null  object
#  3   state                           355634 non-null  object
#  4   state_code                      355634 non-null  object
#  5   property_type                   355634 non-null  object
#  6   property_type_id                355634 non-null  int64
#  7   median_sale_price               355634 non-null  float64
#  8   median_sale_price_mom           339045 non-null  float64
#  9   median_sale_price_yoy           308643 non-null  float64
#  10  median_list_price               333142 non-null  float64
#  11  median_list_price_mom           316512 non-null  float64
#  12  median_list_price_yoy           293745 non-null  float64
#  13  median_ppsf                     355443 non-null  float64
#  14  median_ppsf_mom                 338866 non-null  float64
#  15  median_ppsf_yoy                 308506 non-null  float64
#  16  median_list_ppsf                333073 non-null  float64
#  17  median_list_ppsf_mom            316459 non-null  float64
#  18  median_list_ppsf_yoy            293696 non-null  float64
#  19  homes_sold                      355634 non-null  int64
#  20  homes_sold_mom                  339045 non-null  float64
#  21  homes_sold_yoy                  308643 non-null  float64
#  22  pending_sales                   275829 non-null  float64
#  23  pending_sales_mom               243853 non-null  float64
#  24  pending_sales_yoy               235542 non-null  float64
#  25  new_listings                    333195 non-null  float64
#  26  new_listings_mom                316561 non-null  float64
#  27  new_listings_yoy                293796 non-null  float64
#  28  inventory                       320051 non-null  float64
#  29  inventory_mom                   304042 non-null  float64
#  30  inventory_yoy                   284274 non-null  float64
#  31  median_dom                      354594 non-null  float64
#  32  median_dom_mom                  338032 non-null  float64
#  33  median_dom_yoy                  307736 non-null  float64
#  34  avg_sale_to_list                346622 non-null  float64
#  35  avg_sale_to_list_mom            330815 non-null  float64
#  36  avg_sale_to_list_yoy            302894 non-null  float64
#  37  sold_above_list                 355634 non-null  float64
#  38  sold_above_list_mom             339045 non-null  float64
#  39  sold_above_list_yoy             308643 non-null  float64
#  40  price_drops                     240881 non-null  float64
#  41  price_drops_mom                 222011 non-null  float64
#  42  price_drops_yoy                 198020 non-null  float64
#  43  off_market_in_two_weeks         275829 non-null  float64
#  44  off_market_in_two_weeks_mom     243853 non-null  float64
#  45  off_market_in_two_weeks_yoy     235542 non-null  float64
#  46  parent_metro_region             355634 non-null  object
#  47  parent_metro_region_metro_code  355634 non-null  int64
#  48  last_updated                    355634 non-null  object
#  49  zipcode                         355634 non-null  object
# dtypes: float64(38), int64(3), object(9)
# memory usage: 138.4+ MB
#        property_type_id  median_sale_price  median_sale_price_mom  \
# count     355634.000000       3.556340e+05          339045.000000
# mean           3.853937       2.379991e+05               0.034234
# std            4.415965       1.907007e+05               0.652228
# min           -1.000000       7.000000e+02              -0.996642
# 25%           -1.000000       1.320000e+05              -0.022105
# 50%            4.000000       1.972500e+05               0.000000
# 75%            6.000000       2.930000e+05               0.039179
# max           13.000000       1.237500e+07             189.000000
#
#        median_sale_price_yoy  median_list_price  median_list_price_mom  \
# count          308643.000000       3.331420e+05          316512.000000
# mean                0.189473       2.552722e+05               0.059348
# std                 1.463891       1.947910e+05               3.346990
# min                -0.996526       5.500000e+02              -0.998206
# 25%                -0.011628       1.447500e+05              -0.026846
# 50%                 0.089474       2.124500e+05               0.000000
# 75%                 0.222824       3.124000e+05               0.042802
# max               263.623955       9.438000e+06            1179.904523
#
#        median_list_price_yoy   median_ppsf  median_ppsf_mom  median_ppsf_yoy  \
# count          293745.000000  3.554430e+05    338866.000000    308506.000000
# mean                0.201837  2.289038e+02         0.251553         0.164725
# std                 4.372476  3.495947e+04       128.810741         5.537050
# min                -0.998741  3.731579e-01        -0.999699        -0.999028
# 25%                -0.011351  8.048938e+01        -0.012462         0.010552
# 50%                 0.080432  1.107078e+02         0.000000         0.084252
# 75%                 0.198462  1.497586e+02         0.028302         0.189486
# max               759.000000  1.203300e+07     74950.076824      2779.607143
#
#        ...  sold_above_list  sold_above_list_mom  sold_above_list_yoy  \
# count  ...    355634.000000        339045.000000        308643.000000
# mean   ...         0.195390             0.000908             0.025916
# std    ...         0.225558             0.122052             0.231852
# min    ...         0.000000            -1.000000            -1.000000
# 25%    ...         0.000000            -0.018433            -0.039382
# 50%    ...         0.142857             0.000000             0.000000
# 75%    ...         0.279052             0.020816             0.090909
# max    ...         1.000000             1.000000             1.000000
#
#          price_drops  price_drops_mom  price_drops_yoy  \
# count  240881.000000    222011.000000    198020.000000
# mean        0.551358         0.008151         0.012698
# std         0.221536         0.170467         0.230267
# min         0.002674        -0.925000        -0.969697
# 25%         0.400000        -0.071429        -0.111111
# 50%         0.531250         0.003415         0.010251
# 75%         0.692308         0.089831         0.138235
# max         1.000000         0.950820         0.983607
#
#        off_market_in_two_weeks  off_market_in_two_weeks_mom  \
# count            275829.000000                243853.000000
# mean                  0.340675                    -0.000158
# std                   0.276738                     0.298809
# min                   0.000000                    -1.333333
# 25%                   0.121212                    -0.116667
# 50%                   0.333333                     0.000000
# 75%                   0.500000                     0.115385
# max                   2.000000                     1.333333
#
#        off_market_in_two_weeks_yoy  parent_metro_region_metro_code
# count                235542.000000                   355634.000000
# mean                      0.020618                    25065.305325
# std                       0.304436                     9366.077954
# min                      -2.000000                    10180.000000
# 25%                      -0.105907                    19124.000000
# 50%                       0.000000                    23104.000000
# 75%                       0.156566                    26420.000000
# max                       1.333333                    49820.000000
#
# [8 rows x 41 columns]

# %%
#Do some discovery of data here

#Why isn't City Populated?
#perhaps we can pull a lit of zip codes for dallas, austin, houston and filter on those zip codes and populate those cities. 


#might be because we're pulling in quarterly data, try exporting monthly supply from site and importing through CSV?

#supply collumns have no data should drop them
#months_of_supply
#months_of_supply_mom
#months_of_supply_yoy

#Last updated = 11/20/2022 
#can likely pull in data through end of november if we update it

# %%
texas_merge_df.to_csv('redfin_texas_export_new.csv')
