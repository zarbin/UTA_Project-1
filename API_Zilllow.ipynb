# %%
import requests
import json

url = "https://zillow-com1.p.rapidapi.com/propertyExtendedSearch"

querystring = {"location":"Austin, TX","home_type":"Houses"}

headers = {
	"X-RapidAPI-Key": "980a3fd58dmshbf5d911ea1d6484p19753bjsn7a9a104f76b8",
	"X-RapidAPI-Host": "zillow-com1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)
response_json = response.json()

#print(response.text)
print(json.dumps(response_json, indent=4))
# Out:
# {
#     "props": [
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 4922.28,
#             "address": "3706 Denehoe Cv, Austin, TX 78725",
#             "imgSrc": "https://photos.zillowstatic.com/fp/ab538bf04375501d47fc1c3e64095dbe-p_e.jpg",
#             "price": 295000,
#             "bedrooms": 4,
#             "longitude": -97.58753,
#             "latitude": 30.234795,
#             "listingStatus": "FOR_SALE",
#             "zpid": "29462526",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 3,
#             "livingArea": 1624,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 6076.62,
#             "address": "12821 Stoney Ridge Bnd, Del Valle, TX 78617",
#             "imgSrc": "https://photos.zillowstatic.com/fp/d21985876c197082e7af539a44723a24-p_e.jpg",
#             "price": 360000,
#             "bedrooms": 4,
#             "longitude": -97.63293,
#             "latitude": 30.161036,
#             "listingStatus": "FOR_SALE",
#             "zpid": "145658188",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 3,
#             "livingArea": 2281,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 6490.44,
#             "address": "7005 Carwill Dr, Austin, TX 78724",
#             "imgSrc": "https://photos.zillowstatic.com/fp/95ffc83bdc54dedef0bb16c1143d7834-p_e.jpg",
#             "price": 289990,
#             "bedrooms": 3,
#             "longitude": -97.643745,
#             "latitude": 30.302465,
#             "listingStatus": "FOR_SALE",
#             "zpid": "58301316",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 2,
#             "livingArea": 1266,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 9234.72,
#             "address": "11515 Easy St, Austin, TX 78748",
#             "imgSrc": "https://photos.zillowstatic.com/fp/d330ea345410f35af79ad2e29ac6cd48-p_e.jpg",
#             "price": 486900,
#             "bedrooms": 3,
#             "longitude": -97.831894,
#             "latitude": 30.151669,
#             "listingStatus": "FOR_SALE",
#             "zpid": "29515279",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 2,
#             "livingArea": 1340,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 6547.068,
#             "address": "2537 Lavendale Ct, Austin, TX 78748",
#             "imgSrc": "https://photos.zillowstatic.com/fp/7c6fc560827089bef4d302c14a34b39b-p_e.jpg",
#             "price": 470000,
#             "bedrooms": 3,
#             "longitude": -97.84046,
#             "latitude": 30.156364,
#             "listingStatus": "FOR_SALE",
#             "zpid": "58317417",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 2,
#             "livingArea": 1884,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 6024.348,
#             "address": "5505 Fence Row, Austin, TX 78744",
#             "imgSrc": "https://photos.zillowstatic.com/fp/b45936d69ad30e478cae4ce22795ccd7-p_e.jpg",
#             "price": 389000,
#             "bedrooms": 4,
#             "longitude": -97.73227,
#             "latitude": 30.19664,
#             "listingStatus": "FOR_SALE",
#             "zpid": "29467278",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 2,
#             "livingArea": 1532,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 8145.72,
#             "address": "9512 China Rose Dr, Austin, TX 78724",
#             "imgSrc": "https://photos.zillowstatic.com/fp/61a0c5d7d684c6305e552ef7d0280eb9-p_e.jpg",
#             "price": 435000,
#             "bedrooms": 4,
#             "longitude": -97.62308,
#             "latitude": 30.278683,
#             "listingStatus": "FOR_SALE",
#             "zpid": "111372641",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 3,
#             "livingArea": 2491,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 0.339,
#             "address": "4206 McKinney Falls Pkwy, Austin, TX 78744",
#             "imgSrc": "https://photos.zillowstatic.com/fp/ee7fb74ed12703eb110356b83cc98271-p_e.jpg",
#             "price": 285000,
#             "bedrooms": 3,
#             "longitude": -97.69944,
#             "latitude": 30.191557,
#             "listingStatus": "FOR_SALE",
#             "zpid": "29468391",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 2,
#             "livingArea": 1428,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "acres",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 7666.56,
#             "address": "12113 Verchota Dr, Austin, TX 78748",
#             "imgSrc": "https://photos.zillowstatic.com/fp/10c6a70d5d303e8a223709f76a981149-p_e.jpg",
#             "price": 447000,
#             "bedrooms": 3,
#             "longitude": -97.83995,
#             "latitude": 30.145405,
#             "listingStatus": "FOR_SALE",
#             "zpid": "80102859",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 3,
#             "livingArea": 1507,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 8860.104,
#             "address": "8505 Spring Valley Dr, Austin, TX 78736",
#             "imgSrc": "https://photos.zillowstatic.com/fp/f78ed50f50bba9549d97e05ab2a84f28-p_e.jpg",
#             "price": 469000,
#             "bedrooms": 3,
#             "longitude": -97.89828,
#             "latitude": 30.239298,
#             "listingStatus": "FOR_SALE",
#             "zpid": "29477896",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 3,
#             "livingArea": 1582,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 0.295,
#             "address": "5904 Taylor Draper Cv, Austin, TX 78759",
#             "imgSrc": "https://photos.zillowstatic.com/fp/25ab5bef53c5da06c0d53a48f0a416de-p_e.jpg",
#             "price": 749000,
#             "bedrooms": 4,
#             "longitude": -97.75663,
#             "latitude": 30.41658,
#             "listingStatus": "FOR_SALE",
#             "zpid": "29367563",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 3,
#             "livingArea": 2423,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "acres",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 10454.4,
#             "address": "9501 Meadowheath Dr, Austin, TX 78729",
#             "imgSrc": "https://photos.zillowstatic.com/fp/8884f98a2cce846542542a06761961d6-p_e.jpg",
#             "price": 425000,
#             "bedrooms": 4,
#             "longitude": -97.77968,
#             "latitude": 30.461945,
#             "listingStatus": "FOR_SALE",
#             "zpid": "29555087",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 2,
#             "livingArea": 1838,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 5244.624,
#             "address": "1445 Sir Thopas Trl, Austin, TX 78748",
#             "imgSrc": "https://photos.zillowstatic.com/fp/85542ed8ddc03360aa73bf5398ad825c-p_e.jpg",
#             "price": 399999,
#             "bedrooms": 3,
#             "longitude": -97.83005,
#             "latitude": 30.153736,
#             "listingStatus": "FOR_SALE",
#             "zpid": "58317342",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 2,
#             "livingArea": 1271,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 10428.264,
#             "address": "12128 Harpster Bnd, Austin, TX 78717",
#             "imgSrc": "https://photos.zillowstatic.com/fp/e448cb71f7c260ebb5f6f1f3a9dce623-p_e.jpg",
#             "price": 620000,
#             "bedrooms": 3,
#             "longitude": -97.79884,
#             "latitude": 30.493256,
#             "listingStatus": "FOR_SALE",
#             "zpid": "250825240",
#             "listingSubType": {
#                 "is_FSBA": true,
#                 "is_openHouse": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 3,
#             "livingArea": 2252,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 6403.32,
#             "address": "7105 Cherry Beam Path, Austin, TX 78744",
#             "imgSrc": "https://photos.zillowstatic.com/fp/d460141e9b269af272d7ae409a6168ef-p_e.jpg",
#             "price": 625000,
#             "bedrooms": 4,
#             "longitude": -97.72289,
#             "latitude": 30.164387,
#             "listingStatus": "FOR_SALE",
#             "zpid": "145656291",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 3,
#             "livingArea": 2515,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 0.5152,
#             "address": "3501 Vara Dr, Austin, TX 78754",
#             "imgSrc": "https://photos.zillowstatic.com/fp/8df8de2eee2900e5538607a16cf36960-p_e.jpg",
#             "price": 795000,
#             "bedrooms": 3,
#             "longitude": -97.65473,
#             "latitude": 30.33296,
#             "listingStatus": "FOR_SALE",
#             "zpid": "29415556",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 5,
#             "livingArea": 2950,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "acres",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 0.4034,
#             "address": "12612 Capella Trl, Austin, TX 78732",
#             "imgSrc": "https://photos.zillowstatic.com/fp/5f8a6abb1e3a66d958fab71ab936102b-p_e.jpg",
#             "price": 995000,
#             "bedrooms": 6,
#             "longitude": -97.90571,
#             "latitude": 30.36173,
#             "listingStatus": "FOR_SALE",
#             "zpid": "70352545",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 4,
#             "livingArea": 3686,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "acres",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 5131.368,
#             "address": "1704 Constanta Dr, Austin, TX 78753",
#             "imgSrc": "https://photos.zillowstatic.com/fp/1753b56c2e06173b2a67edef694a49e9-p_e.jpg",
#             "price": 570000,
#             "bedrooms": 3,
#             "longitude": -97.647644,
#             "latitude": 30.392124,
#             "listingStatus": "FOR_SALE",
#             "zpid": "145654898",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 3,
#             "livingArea": 2417,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 7993.26,
#             "address": "827 Sussex Dr, Austin, TX 78745",
#             "imgSrc": "https://photos.zillowstatic.com/fp/59b496414b96f76c635da71a830194b6-p_e.jpg",
#             "price": 365000,
#             "bedrooms": 3,
#             "longitude": -97.76269,
#             "latitude": 30.206001,
#             "listingStatus": "FOR_SALE",
#             "zpid": "29487808",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 2,
#             "livingArea": 1006,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 9970.884,
#             "address": "12721 Bright Sky Overlook, Austin, TX 78732",
#             "imgSrc": "https://photos.zillowstatic.com/fp/4285f0f72eea687aa634bd5f4b5b84a0-p_e.jpg",
#             "price": 950000,
#             "bedrooms": 4,
#             "longitude": -97.908424,
#             "latitude": 30.355425,
#             "listingStatus": "FOR_SALE",
#             "zpid": "83813067",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 4,
#             "livingArea": 3249,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 6817.14,
#             "address": "902 Hillside Oaks Dr, Austin, TX 78745",
#             "imgSrc": "https://photos.zillowstatic.com/fp/0cce3ad365baa83b8d0c634b44d7ac04-p_e.jpg",
#             "price": 550000,
#             "bedrooms": 3,
#             "longitude": -97.79326,
#             "latitude": 30.195902,
#             "listingStatus": "FOR_SALE",
#             "zpid": "29497339",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 2,
#             "livingArea": 1235,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 8772.984,
#             "address": "9023 Marthas Dr, Austin, TX 78717",
#             "imgSrc": "https://photos.zillowstatic.com/fp/9da18f983e6f83442d239c5d772aafd6-p_e.jpg",
#             "price": 575000,
#             "bedrooms": 4,
#             "longitude": -97.74414,
#             "latitude": 30.504807,
#             "listingStatus": "FOR_SALE",
#             "zpid": "29577455",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 3,
#             "livingArea": 2328,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 4791.6,
#             "address": "9501 Hunter Ln, Austin, TX 78748",
#             "imgSrc": "https://photos.zillowstatic.com/fp/a233f0957772b783c62a58424cd88c07-p_e.jpg",
#             "price": 497000,
#             "bedrooms": 3,
#             "longitude": -97.80025,
#             "latitude": 30.166615,
#             "listingStatus": "FOR_SALE",
#             "zpid": "145656496",
#             "listingSubType": {
#                 "is_FSBA": true,
#                 "is_openHouse": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 3,
#             "livingArea": 1727,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 5427.576,
#             "address": "3107 Sacbe Cv, Austin, TX 78745",
#             "imgSrc": "https://photos.zillowstatic.com/fp/293236e8b360116ffeda69bb5b239aa9-p_e.jpg",
#             "price": 749000,
#             "bedrooms": 3,
#             "longitude": -97.8319,
#             "latitude": 30.197042,
#             "listingStatus": "FOR_SALE",
#             "zpid": "124839880",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 2,
#             "livingArea": 1666,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 8494.2,
#             "address": "11317 Stormy Ridge Rd, Austin, TX 78739",
#             "imgSrc": "https://photos.zillowstatic.com/fp/20fbcfc9fb68a62f07f9646a9d8b5387-p_e.jpg",
#             "price": 499990,
#             "bedrooms": 3,
#             "longitude": -97.86855,
#             "latitude": 30.171602,
#             "listingStatus": "FOR_SALE",
#             "zpid": "29511854",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 2,
#             "livingArea": 1445,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 8999.496,
#             "address": "1014 S Meadows Dr, Austin, TX 78758",
#             "imgSrc": "https://photos.zillowstatic.com/fp/8f55e9c49f05864c6d4128f61d887804-p_e.jpg",
#             "price": 489900,
#             "bedrooms": 3,
#             "longitude": -97.69588,
#             "latitude": 30.376162,
#             "listingStatus": "FOR_SALE",
#             "zpid": "29432570",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 2,
#             "livingArea": 1631,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 7945.344,
#             "address": "2205 N Plains Ave, Austin, TX 78757",
#             "imgSrc": "https://photos.zillowstatic.com/fp/d215442ad71a61365c003398d0733f55-p_e.jpg",
#             "price": 850000,
#             "bedrooms": 3,
#             "longitude": -97.72924,
#             "latitude": 30.35603,
#             "listingStatus": "FOR_SALE",
#             "zpid": "29423048",
#             "listingSubType": {
#                 "is_FSBA": true,
#                 "is_openHouse": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 3,
#             "livingArea": 1725,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 7191.756,
#             "address": "8503 Cornwall Dr, Austin, TX 78748",
#             "imgSrc": "https://photos.zillowstatic.com/fp/5958a50bcd40b80a62e7d0ee6cb9ae49-p_e.jpg",
#             "price": 575000,
#             "bedrooms": 3,
#             "longitude": -97.79815,
#             "latitude": 30.178364,
#             "listingStatus": "FOR_SALE",
#             "zpid": "29508516",
#             "listingSubType": {
#                 "is_FSBA": true,
#                 "is_openHouse": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 2,
#             "livingArea": 1231,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 8559.54,
#             "address": "8408 Dixon Dr, Austin, TX 78745",
#             "imgSrc": "https://photos.zillowstatic.com/fp/787b851d5b98000419ef0f53865c013e-p_e.jpg",
#             "price": 450000,
#             "bedrooms": 3,
#             "longitude": -97.82533,
#             "latitude": 30.192648,
#             "listingStatus": "FOR_SALE",
#             "zpid": "63838573",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 2,
#             "livingArea": 1310,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 8054.244,
#             "address": "8600 Delaware Ct, Austin, TX 78758",
#             "imgSrc": "https://photos.zillowstatic.com/fp/46516eafe18da6f9c0a53ed7f8add222-p_e.jpg",
#             "price": 389000,
#             "bedrooms": 3,
#             "longitude": -97.70501,
#             "latitude": 30.357359,
#             "listingStatus": "FOR_SALE",
#             "zpid": "29423513",
#             "listingSubType": {
#                 "is_FSBA": true,
#                 "is_openHouse": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 1,
#             "livingArea": 923,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 5693.292,
#             "address": "4605 Leatherleaf Trl, Austin, TX 78744",
#             "imgSrc": "https://photos.zillowstatic.com/fp/b00f154f60ee26f6dd559e0b5d86b8c0-p_e.jpg",
#             "price": 349900,
#             "bedrooms": 3,
#             "longitude": -97.74777,
#             "latitude": 30.190216,
#             "listingStatus": "FOR_SALE",
#             "zpid": "29467550",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 2,
#             "livingArea": 1244,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 10280.16,
#             "address": "11905 Knights Brg, Austin, TX 78759",
#             "imgSrc": "https://photos.zillowstatic.com/fp/318f25722e50515fd02b3878dddcacb1-p_e.jpg",
#             "price": 840000,
#             "bedrooms": 3,
#             "longitude": -97.76834,
#             "latitude": 30.430182,
#             "listingStatus": "FOR_SALE",
#             "zpid": "29371419",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 2,
#             "livingArea": 1864,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 5998.212,
#             "address": "6704 Taomina Dr, Austin, TX 78739",
#             "imgSrc": "https://photos.zillowstatic.com/fp/c547cffdcb6bb95e3d32553650ad6dd0-p_e.jpg",
#             "price": 994900,
#             "bedrooms": 4,
#             "longitude": -97.91399,
#             "latitude": 30.168453,
#             "listingStatus": "FOR_SALE",
#             "zpid": "336746469",
#             "listingSubType": {
#                 "is_FSBA": true,
#                 "is_openHouse": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 4,
#             "livingArea": 2980,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 9082.26,
#             "address": "7519 Robert Kleburg Ln, Austin, TX 78749",
#             "imgSrc": "https://photos.zillowstatic.com/fp/5414ac75f83c2c39c145b21e9526d3a9-p_e.jpg",
#             "price": 809000,
#             "bedrooms": 4,
#             "longitude": -97.8723,
#             "latitude": 30.22482,
#             "listingStatus": "FOR_SALE",
#             "zpid": "29484293",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 3,
#             "livingArea": 2906,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 9413.316,
#             "address": "14316 Padbrook Park Cv, Austin, TX 78717",
#             "imgSrc": "https://photos.zillowstatic.com/fp/6b434dba156fd9e1b1b648b61af6c075-p_e.jpg",
#             "price": 719000,
#             "bedrooms": 5,
#             "longitude": -97.78541,
#             "latitude": 30.496218,
#             "listingStatus": "FOR_SALE",
#             "zpid": "60335768",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 4,
#             "livingArea": 3229,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 8720.712,
#             "address": "8536 Steamline Cir, Austin, TX 78745",
#             "imgSrc": "https://photos.zillowstatic.com/fp/cf9cb74ce6b8190f84da0ef1dada8024-p_e.jpg",
#             "price": 549000,
#             "bedrooms": 4,
#             "longitude": -97.81488,
#             "latitude": 30.186586,
#             "listingStatus": "FOR_SALE",
#             "zpid": "58316392",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 3,
#             "livingArea": 2479,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 0.2574,
#             "address": "1928 Wimberly Ln, Austin, TX 78735",
#             "imgSrc": "https://photos.zillowstatic.com/fp/9e23ec88cb478defb036c31452a27c7b-p_e.jpg",
#             "price": 1950000,
#             "bedrooms": 5,
#             "longitude": -97.876564,
#             "latitude": 30.293774,
#             "listingStatus": "FOR_SALE",
#             "zpid": "70336924",
#             "listingSubType": {
#                 "is_FSBA": true,
#                 "is_openHouse": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 4,
#             "livingArea": 4310,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "acres",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 6094.044,
#             "address": "4200 Sojourner St, Austin, TX 78725",
#             "imgSrc": "https://photos.zillowstatic.com/fp/29a40c73beb8f81ff1255cbcc1108180-p_e.jpg",
#             "price": 325000,
#             "bedrooms": 3,
#             "longitude": -97.58826,
#             "latitude": 30.24176,
#             "listingStatus": "FOR_SALE",
#             "zpid": "29459988",
#             "listingSubType": {
#                 "is_FSBA": true,
#                 "is_openHouse": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 2,
#             "livingArea": 1466,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 7418.268,
#             "address": "1816 Forestglade Dr, Austin, TX 78745",
#             "imgSrc": "https://photos.zillowstatic.com/fp/79609347a7501214f6001f7c60464c73-p_e.jpg",
#             "price": 509000,
#             "bedrooms": 3,
#             "longitude": -97.79033,
#             "latitude": 30.224789,
#             "listingStatus": "FOR_SALE",
#             "zpid": "29479992",
#             "listingSubType": {
#                 "is_FSBA": true,
#                 "is_openHouse": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 1,
#             "livingArea": 1000,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         },
#         {
#             "dateSold": null,
#             "propertyType": "SINGLE_FAMILY",
#             "lotAreaValue": 4948.416,
#             "address": "3609 Bratton Ridge Xing, Austin, TX 78728",
#             "imgSrc": "https://photos.zillowstatic.com/fp/c54809a4a6a38f3f6e1d21045da7be0d-p_e.jpg",
#             "price": 499900,
#             "bedrooms": 4,
#             "longitude": -97.683235,
#             "latitude": 30.462145,
#             "listingStatus": "FOR_SALE",
#             "zpid": "29454479",
#             "listingSubType": {
#                 "is_FSBA": true
#             },
#             "contingentListingType": null,
#             "daysOnZillow": -1,
#             "bathrooms": 3,
#             "livingArea": 2125,
#             "country": "USA",
#             "currency": "USD",
#             "lotAreaUnit": "sqft",
#             "hasImage": true
#         }
#     ],
#     "resultsPerPage": 40,
#     "totalPages": 20,
#     "totalResultCount": 2476,
#     "currentPage": 1
# }
